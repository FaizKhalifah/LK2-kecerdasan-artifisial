# %%
import pandas as pd
data = pd.read_csv("Reviews-search-for-good-profiling.csv")
filtered = data[data["BoyerMoore_count"] >= 20]
filtered
# Out:
#                                             original_text  KMP_count  \
# 59774   these are good but are not sweet! good, good, ...         34
# 253600  spookylicious pop-tarts: a cautionary tale.<br...         22
#
#                                               KMP_indices  KMP_time_ms  \
# 59774   [10, 34, 40, 46, 52, 58, 64, 70, 76, 82, 88, 9...       0.0353
# 253600  [130, 268, 322, 518, 942, 1157, 1386, 1528, 23...       1.3391
#
#         RabinKarp_count                                  RabinKarp_indices  \
# 59774                34  [10, 34, 40, 46, 52, 58, 64, 70, 76, 82, 88, 9...
# 253600               22  [130, 268, 322, 518, 942, 1157, 1386, 1528, 23...
#
#         RabinKarp_time_ms  BoyerMoore_count  \
# 59774              0.0782                34
# 253600             3.1632                22
#
#                                        BoyerMoore_indices  BoyerMoore_time_ms
# 59774   [10, 34, 40, 46, 52, 58, 64, 70, 76, 82, 88, 9...              0.0359
# ...
